# %%
import pandas as pd
name_basics = pd.read_csv('name.basics.tsv', sep='\t', low_memory=False)

# %%
name_basics.head(5)
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0053137,tt0050419,tt0072308,tt0031983
# 1  tt0071877,tt0117057,tt0038355,tt0037382
# 2  tt0049189,tt0057345,tt0054452,tt0056404
# 3  tt0080455,tt0078723,tt0077975,tt0072562
# 4  tt0050986,tt0050976,tt0083922,tt0060827

# %%
title_akas = pd.read_csv('title.akas.tsv', sep='\t', low_memory=False)

# %%
title_akas.head(10)
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
# 5  tt0000001         6                 Carmencita     US       \N
# 6  tt0000001         7                 Carmencita     \N       \N
# 7  tt0000001         8                    カルメンチータ     JP       ja
# 8  tt0000002         1     Le clown et ses chiens     \N       \N
# 9  tt0000002         2     Le clown et ses chiens     FR       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0
# 5  imdbDisplay             \N               0
# 6     original             \N               1
# 7  imdbDisplay             \N               0
# 8     original             \N               1
# 9  imdbDisplay             \N               0

# %%
title_basics = pd.read_csv('title.basics.tsv', sep='\t', low_memory=False)

# %%
title_basics.head(5)
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
title_crew = pd.read_csv('title.crew.tsv', sep='\t', low_memory=False)

# %%
title_crew.head(5)
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690      \N
# 1  tt0000002  nm0721526      \N
# 2  tt0000003  nm0721526      \N
# 3  tt0000004  nm0721526      \N
# 4  tt0000005  nm0005690      \N

# %%
title_episode = pd.read_csv('title.episode.tsv', sep='\t', low_memory=False)

# %%
title_episode.head(5)
# Out:
#       tconst parentTconst seasonNumber episodeNumber
# 0  tt0020666   tt15180956            1             2
# 1  tt0021166   tt15180956            1             3
# 2  tt0021612   tt15180956            2             2
# 3  tt0021655   tt15180956            2             5
# 4  tt0021663   tt15180956            2             6

# %%
title_principals = pd.read_csv('title.principals.tsv', sep='\t', low_memory=False)

# %%
title_principals.head(5)
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0374658  cinematographer  director of photography
# 3  tt0000002         1  nm0721526         director                       \N
# 4  tt0000002         2  nm1335271         composer                       \N
#
#   characters
# 0   ["Self"]
# 1         \N
# 2         \N
# 3         \N
# 4         \N

# %%
title_ratings = pd.read_csv('title.ratings.tsv', sep='\t', low_memory=False)

# %%
title_ratings.head(5)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1825
# 1  tt0000002            6.0       233
# 2  tt0000003            6.5      1576
# 3  tt0000004            6.1       151
# 4  tt0000005            6.2      2404

# %%
title_basics.head(5)
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
#Merging the title_ratings and title_basics dataframes
merged_frame = pd.merge(title_ratings, title_basics[['tconst', 'originalTitle']], on = 'tconst', how='inner')

# %%
merged_frame.head(5)
# Out:
#       tconst  averageRating  numVotes           originalTitle
# 0  tt0000001            5.7      1825              Carmencita
# 1  tt0000002            6.0       233  Le clown et ses chiens
# 2  tt0000003            6.5      1576          Pauvre Pierrot
# 3  tt0000004            6.1       151             Un bon bock
# 4  tt0000005            6.2      2404        Blacksmith Scene

# %%
#retriving ones with number of votes about 100
merged_frames_100 = merged_frame.copy().loc[merged_frame['numVotes'] >= 100]

# %%
merged_frames_100.head(5)
# Out:
#       tconst  averageRating  numVotes           originalTitle
# 0  tt0000001            5.7      1825              Carmencita
# 1  tt0000002            6.0       233  Le clown et ses chiens
# 2  tt0000003            6.5      1576          Pauvre Pierrot
# 3  tt0000004            6.1       151             Un bon bock
# 4  tt0000005            6.2      2404        Blacksmith Scene

# %%
merged_frames_100.shape
# Out:
# (284032, 4)

# %%
merged_frame_100.shape
# Out:
# (284032, 4)

# %%
merged_frame_100.head(5)
# Out:
#       tconst  averageRating  numVotes           originalTitle
# 0  tt0000001            5.7      1825              Carmencita
# 1  tt0000002            6.0       233  Le clown et ses chiens
# 2  tt0000003            6.5      1576          Pauvre Pierrot
# 3  tt0000004            6.1       151             Un bon bock
# 4  tt0000005            6.2      2404        Blacksmith Scene

# %%
#restrict from chaining
pd.options.mode.chained_assignment = None 

#calculate the average number of votes
averageNumberOfVotes = merged_frame_100["numVotes"].mean() #4020.0313450597114

# %%
#calculate the quantile number of votes
NumberOfVotes_quantile = merged_frame_100["numVotes"].quantile()

# %%
averageNumberOfVotes
# Out:
# 4020.0313450597114

# %%
NumberOfVotes_quantile
# Out:
# 321.0

# %%
# Calculating ranking = (numVotes / averageNumberOfVotes) * averageRating
merged_frame_100['ranking'] = merged_frame_100.apply(lambda row: (row.numVotes / averageNumberOfVotes) * row.averageRating, axis=1)

# %%
merged_frame_100.head(20)
# Out:
#        tconst  averageRating  numVotes  \
# 0   tt0000001            5.7      1825
# 1   tt0000002            6.0       233
# 2   tt0000003            6.5      1576
# 3   tt0000004            6.1       151
# 4   tt0000005            6.2      2404
# 5   tt0000006            5.2       156
# 6   tt0000007            5.4       750
# 7   tt0000008            5.5      1977
# 8   tt0000009            5.9       190
# 9   tt0000010            6.9      6572
# 10  tt0000011            5.2       327
# 11  tt0000012            7.4     11262
# 12  tt0000013            5.8      1740
# 13  tt0000014            7.1      5052
# 14  tt0000015            6.2       953
# 15  tt0000016            5.9      1339
# 16  tt0000017            4.6       293
# 17  tt0000018            5.3       540
# 19  tt0000020            5.0       315
# 20  tt0000022            5.1       996
#
#                                         originalTitle    ranking
# 0                                          Carmencita   2.587666
# 1                              Le clown et ses chiens   0.347758
# 2                                      Pauvre Pierrot   2.548239
# 3                                         Un bon bock   0.229128
# 4                                    Blacksmith Scene   3.707633
# 5                                   Chinese Opium Den   0.201789
# 6         Corbett and Courtney Before the Kinetograph   1.007455
# 7              Edison Kinetoscopic Record of a Sneeze   2.704830
# 8                                          Miss Jerry   0.278854
# 9                 La sortie de l'usine Lumière à Lyon  11.280211
# 10                            Akrobatisches Potpourri   0.422982
# 11                   L'arrivée d'un train à La Ciotat  20.730883
# 12  Le débarquement du congrès de photographie à Lyon   2.510428
# 13                                  L'arroseur arrosé   8.922617
# 14                                Autour d'une cabine   1.469790
# 15                             Barque sortant du port   1.965184
# 16                           Italienischer Bauerntanz   0.335271
# 17                               Das boxende Känguruh   0.711935
# 19                                     The Derby 1895   0.391788
# 20                                      Les forgerons   1.263572

# %%
top_15 = merged_frame_100.nlargest(15, 'ranking')

# %%
#Task A: Top 15 movies with a min of  100 votes with Ranking
top_15
# Out:
#            tconst  averageRating  numVotes  \
# 82170   tt0111161            9.3   2468745
# 248905  tt0468569            9.0   2423164
# 616230  tt1375666            8.8   2174026
# 429678  tt0944947            9.2   1879718
# 98614   tt0137523            8.8   1943311
# 81953   tt0110912            8.9   1911447
# 81078   tt0109830            8.8   1908337
# 45931   tt0068646            9.2   1706310
# 96471   tt0133093            8.7   1762913
# 89956   tt0120737            8.8   1733446
# 113644  tt0167260            8.9   1712161
# 419634  tt0903747            9.4   1586852
# 392833  tt0816692            8.6   1618979
# 113645  tt0167261            8.7   1547924
# 604507  tt1345836            8.4   1580208
#
#                                             originalTitle      ranking
# 82170                            The Shawshank Redemption  5711.231214
# 248905                                    The Dark Knight  5424.951730
# 616230                                          Inception  4759.024783
# 429678                                    Game of Thrones  4301.808647
# 98614                                          Fight Club  4253.980960
# 81953                                        Pulp Fiction  4231.777526
# 81078                                        Forrest Gump  4177.421557
# 45931                                       The Godfather  3904.957612
# 96471                                          The Matrix  3815.229729
# 89956   The Lord of the Rings: The Fellowship of the Ring  3794.578572
# 113644      The Lord of the Rings: The Return of the King  3790.575643
# 419634                                       Breaking Bad  3710.520521
# 392833                                       Interstellar  3463.460407
# 113645              The Lord of the Rings: The Two Towers  3349.958656
# 604507                              The Dark Knight Rises  3301.901418

# %%
title_list = list(top_15['originalTitle'])

# %%
#List of the Title of top 15 Movies
title_list
# Out:
# ['The Shawshank Redemption',
#  'The Dark Knight',
#  'Inception',
#  'Game of Thrones',
#  'Fight Club',
#  'Pulp Fiction',
#  'Forrest Gump',
#  'The Godfather',
#  'The Matrix',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'The Lord of the Rings: The Return of the King',
#  'Breaking Bad',
#  'Interstellar',
#  'The Lord of the Rings: The Two Towers',
#  'The Dark Knight Rises']

# %%
#
merged_frame_100_top15= top_15.sort_values('averageRating',ascending=False)

# %%
merged_frame_100_top15.head(10)
# Out:
#            tconst  averageRating  numVotes  \
# 419634  tt0903747            9.4   1586852
# 82170   tt0111161            9.3   2468745
# 429678  tt0944947            9.2   1879718
# 45931   tt0068646            9.2   1706310
# 248905  tt0468569            9.0   2423164
# 81953   tt0110912            8.9   1911447
# 113644  tt0167260            8.9   1712161
# 616230  tt1375666            8.8   2174026
# 98614   tt0137523            8.8   1943311
# 81078   tt0109830            8.8   1908337
#
#                                         originalTitle      ranking
# 419634                                   Breaking Bad  3710.520521
# 82170                        The Shawshank Redemption  5711.231214
# 429678                                Game of Thrones  4301.808647
# 45931                                   The Godfather  3904.957612
# 248905                                The Dark Knight  5424.951730
# 81953                                    Pulp Fiction  4231.777526
# 113644  The Lord of the Rings: The Return of the King  3790.575643
# 616230                                      Inception  4759.024783
# 98614                                      Fight Club  4253.980960
# 81078                                    Forrest Gump  4177.421557

# %%
import matplotlib.pyplot as plt

# %%
pop=merged_frame_100_top15.sort_values('originalTitle',ascending = False)
plt.figure(figsize=(12,4))

plt.barh(pop['originalTitle'].head(10),pop['averageRating'].head(10), align='center',
        color='skyblue')
plt.gca().invert_yaxis()
plt.xlabel("Rating")
plt.title('Popular Title')
# Out:
# Text(0.5, 1.0, 'Popular Title')
